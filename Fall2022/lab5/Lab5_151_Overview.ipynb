# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %% [markdown]
# Skip problem #1

# %% [markdown]
# Hint of #2

# %%
# Part a
# Setting up equation
k, t = symbols('k t')

y = cos(k * t)
ddy = diff(y, t, 2)
eqn = 4 * ddy + 25 * y
soln = solve(eqn, k)
# soln has 4 terms. k is a constant number, which should not contain t
# discard some terms in soln
# implement the rest

# %%
# Part b
# Setting up equation
t, A, B = symbols('t A B')

# let k be one of the soln
"""
k = ???
"""
y = A * sin(k * t) + B * cos(k * t)
ddy = diff(y, t, 2)
eqn = 4 * ddy + 25 * y
print(eqn.simplify())
# soln has 4 terms. k is a constant number, which should not contain t
# discard some terms in soln
# implement the rest
# Out:
# 0

# %% [markdown]
# Hint of #3 Part c

# %%
# Now find the equations of the tangent lines
g = ((t - 2)/(2 * t + 1))**9

"""
horizontal tangent line is where the derivative is 0
"""
# Out:
# [2]
# '\nhorizontal tangent line is where the derivative is 0\n'

# %% [markdown]
# Hint of #4

# %%
matplotlib notebook

# %%
mu, W, x = symbols('mu W x')
F = mu * W / (mu * sin(x) + cos(x))

plot(F.subs({W : 100, mu : 0.6}), (x,-pi,pi) , ylim=(-100,100))
# Out:
# <img src="data:image/png;base64,..." width="712">
